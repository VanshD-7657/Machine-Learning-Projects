# %% [markdown]
# # Import of Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("credit_score.csv")

# %% [markdown]
# # 1. Understanding the data

# %%
df.head(5)
# Out:
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# 3      19114.12                    NaN                  3  ...        Good
# 4      19114.12            1824.843333                  3  ...        Good
#
# ...

# %%
df.shape
# Out:
# (100000, 28)

# %%
df.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count           84998.000000      100000.000000     100000.00000
# mean             4194.170850          17.091280         22.47443
# std              3183.686167         117.404834        129.05741
# min               303.645417          -1.000000          0.00000
# 25%              1625.568229           3.000000          4.00000
# 50%              3093.745000           6.000000          5.00000
# 75%              5957.448333           7.000000          7.00000
# max             15204.633333        1798.000000       1499.00000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count  100000.000000        100000.000000          98035.000000
# mean       72.466040            21.068780             27.754251
# std       466.422621            14.860104            193.177339
# min         1.000000            -5.000000              0.000000
# ...

# %% [markdown]
# # 2. Data Cleaning

# %%
df.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9985
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       15002
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment       7002
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1965
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           9030
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4479
# Payment_Behaviour               0
# Monthly_Balance              1200
# ...

# %%
df1 = df.copy()

# %%
df1['Annual_Income'].sample(30)
# Out:
# 96810              10585.1
# 18275            138188.84
# 17024            178793.92
# 45953             33287.12
# 92745             40214.54
# 14250              85059.6
# 60684             90541.71
# 95109             20357.69
# 47416             54553.59
# 30063             20616.96
# 44616             64662.04
# 12161             22870.49
# 40113             46150.65
# 80246            160838.32
# 73741             57047.52
# 37380             43430.88
# 52796             76154.56
# 23373              7558.55
# 88491             72458.44
# 72018            9762.175_
# 84713    46874.85000000001
# 17394              8814.92
# 64366             29663.56
# 78622             42447.54
# 23582            20700.455
# 39958             9602.285
# 5555              41507.12
# 63013             24446.05
# 33569              8079.46
# 79929             92807.49
# Name: Annual_Income, dtype: object

# %%
# Changing the datatype and replace the values
df1['Annual_Income'] = df1['Annual_Income'].str.replace('_','').astype(float)

# %%
df1['Monthly_Inhand_Salary'] = df1['Monthly_Inhand_Salary'].replace(np.nan,0)

# %%
df1['Monthly_Inhand_Salary'].isnull().sum()
# Out:
# np.int64(0)

# %%
df1['Num_of_Loan'].unique()
# Out:
# array(['4', '1', '3', '967', '-100', '0', '0_', '2', '3_', '2_', '7', '5',
#        '5_', '6', '8', '8_', '9', '9_', '4_', '7_', '1_', '1464', '6_',
#        '622', '352', '472', '1017', '945', '146', '563', '341', '444',
#        '720', '1485', '49', '737', '1106', '466', '728', '313', '843',
#        '597_', '617', '119', '663', '640', '92_', '1019', '501', '1302',
#        '39', '716', '848', '931', '1214', '186', '424', '1001', '1110',
#        '1152', '457', '1433', '1187', '52', '1480', '1047', '1035',
#        '1347_', '33', '193', '699', '329', '1451', '484', '132', '649',
#        '995', '545', '684', '1135', '1094', '1204', '654', '58', '348',
#        '614', '1363', '323', '1406', '1348', '430', '153', '1461', '905',
#        '1312', '1424', '1154', '95', '1353', '1228', '819', '1006', '795',
#        '359', '1209', '590', '696', '1185_', '1465', '911', '1181', '70',
#        '816', '1369', '143', '1416', '455', '55', '1096', '1474', '420',
# ...

# %%
df1['Num_of_Loan'] = df1['Num_of_Loan'].str.replace('_','').astype(int)
df1['Num_of_Loan'].dtype
# Out:
# dtype('int64')

# %%
df1['Delay_from_due_date'].unique()
# Out:
# array([ 3, -1,  5,  6,  8,  7, 13, 10,  0,  4,  9,  1, 12, 11, 30, 31, 34,
#        27, 14,  2, -2, 16, 17, 15, 23, 22, 21, 18, 19, 52, 51, 48, 53, 26,
#        43, 28, 25, 20, 47, 46, 49, 24, 61, 29, 50, 58, 45, 59, 55, 56, 57,
#        54, 62, 65, 64, 67, 36, 41, 33, 32, 39, 44, 42, 60, 35, 38, -3, 63,
#        40, 37, -5, -4, 66])

# %%
df1['Delay_from_due_date'] = df1['Delay_from_due_date'].replace('-','')

# %%
df1['Num_of_Delayed_Payment'].unique()
# Out:
# array(['7', nan, '4', '8_', '6', '1', '-1', '3_', '0', '8', '5', '3', '9',
#        '12', '15', '17', '10', '2', '2_', '11', '14', '20', '22', '13',
#        '13_', '14_', '16', '12_', '18', '19', '23', '24', '21', '3318',
#        '3083', '22_', '1338', '4_', '26', '11_', '3104', '21_', '25',
#        '10_', '183_', '9_', '1106', '834', '19_', '24_', '17_', '23_',
#        '2672', '20_', '2008', '-3', '538', '6_', '1_', '16_', '27', '-2',
#        '3478', '2420', '15_', '707', '708', '26_', '18_', '3815', '28',
#        '5_', '1867', '2250', '1463', '25_', '7_', '4126', '2882', '1941',
#        '2655', '2628', '132', '3069', '306', '0_', '3539', '3684', '1823',
#        '4128', '1946', '827', '2297', '2566', '904', '182', '929', '3568',
#        '2503', '1552', '2812', '1697', '3764', '851', '3905', '923', '88',
#        '1668', '3253', '808', '2689', '3858', '642', '3457', '1402',
#        '1732', '3154', '847', '3037', '2204', '3103', '1063', '2056',
# ...

# %%
df1['Num_of_Delayed_Payment'] = df1['Num_of_Delayed_Payment'].str.replace('_','')

# %%
df1['Num_of_Delayed_Payment'] = df1['Num_of_Delayed_Payment'].str.replace('-','')

# %%
df1['Num_of_Delayed_Payment'].unique()
# Out:
# array(['7', nan, '4', '8', '6', '1', '3', '0', '5', '9', '12', '15', '17',
#        '10', '2', '11', '14', '20', '22', '13', '16', '18', '19', '23',
#        '24', '21', '3318', '3083', '1338', '26', '3104', '25', '183',
#        '1106', '834', '2672', '2008', '538', '27', '3478', '2420', '707',
#        '708', '3815', '28', '1867', '2250', '1463', '4126', '2882',
#        '1941', '2655', '2628', '132', '3069', '306', '3539', '3684',
#        '1823', '4128', '1946', '827', '2297', '2566', '904', '182', '929',
#        '3568', '2503', '1552', '2812', '1697', '3764', '851', '3905',
#        '923', '88', '1668', '3253', '808', '2689', '3858', '642', '3457',
#        '1402', '1732', '3154', '847', '3037', '2204', '3103', '1063',
#        '2056', '1282', '1841', '2569', '211', '793', '3484', '411',
#        '3491', '2072', '3050', '1049', '2162', '3402', '2753', '1718',
#        '1014', '3260', '3855', '84', '2311', '3251', '1832', '4069',
# ...

# %%
df1['Num_of_Delayed_Payment'] = df1['Num_of_Delayed_Payment'].replace(np.nan,0)

# %%
df1['Num_of_Delayed_Payment'].isnull().sum()
# Out:
# np.int64(0)

# %%
df1['Num_of_Delayed_Payment'] = df1['Num_of_Delayed_Payment'].astype(int)

# %%
df1['Num_of_Delayed_Payment'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 100000 entries, 0 to 99999
# Series name: Num_of_Delayed_Payment
# Non-Null Count   Dtype
# --------------   -----
# 100000 non-null  int64
# dtypes: int64(1)
# memory usage: 781.4 KB

# %%
df1['Credit_Mix'].unique()
# Out:
# array(['_', 'Good', 'Standard', 'Bad'], dtype=object)

# %%
df1['Credit_Mix'] = df1['Credit_Mix'].str.replace('_','None')

# %%
df1['Credit_Mix'].unique()
# Out:
# array(['None', 'Good', 'Standard', 'Bad'], dtype=object)

# %% [markdown]
# # 3. LabelEncoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df1['Credit_Mix'] = le.fit_transform(df1['Credit_Mix'])

# %%
df1['Credit_Mix'].unique()
# Out:
# array([2, 1, 3, 0])

# %%
df1['Outstanding_Debt'].unique()
# Out:
# array(['809.98', '605.03', '1303.01', ..., '3571.7_', '3571.7', '502.38'],
#       shape=(13178,), dtype=object)

# %%
df1['Outstanding_Debt'] = df1['Outstanding_Debt'].str.replace('_','')
df1['Outstanding_Debt'].isnull().sum()
# Out:
# np.int64(0)

# %%
df1['Outstanding_Debt'] = df1['Outstanding_Debt'].astype(float)

# %%
df1['Credit_History_Age'].describe
# Out:
# <bound method NDFrame.describe of 0         22 Years and 1 Months
# 1                           NaN
# 2         22 Years and 3 Months
# 3         22 Years and 4 Months
# 4         22 Years and 5 Months
#                   ...
# 99995     31 Years and 6 Months
# 99996     31 Years and 7 Months
# 99997     31 Years and 8 Months
# 99998     31 Years and 9 Months
# 99999    31 Years and 10 Months
# Name: Credit_History_Age, Length: 100000, dtype: object>

# %%
df1['Credit_History_Age'] = df1['Credit_History_Age'].str.findall(r'(\d+(?:\.\d+)?)')

# %%
df1['Credit_History_Age'] = df1['Credit_History_Age'].replace(np.nan,0)

# %%
df1['Credit_History_Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df1['Monthly_Balance'].unique()
# Out:
# array(['312.49408867943663', '284.62916249607184', '331.2098628537912',
#        ..., 516.8090832742814, 319.1649785257098, 393.6736955618808],
#       shape=(98793,), dtype=object)

# %%
df1['Monthly_Balance'].isnull().sum()
# Out:
# np.int64(1200)

# %%
df1['Monthly_Balance'] = df1['Monthly_Balance'].str.replace('_','')

# %%
df1['Monthly_Balance'] = df1['Monthly_Balance'].replace(np.nan,0)

# %%
df1['Monthly_Balance'] = df1['Monthly_Balance'].astype(float)

# %%
df1['Monthly_Balance'].isnull().sum()
# Out:
# np.int64(0)

# %%
df1['Credit_Score'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Encoding of Credit_Score

# %%
df1['Credit_Score'] = le.fit_transform(df1['Credit_Score'])

# %%
df1['Credit_Score'].unique()
# Out:
# array([0, 2, 1])

# %% [markdown]
# ### 3.SELECTION OF USEFUL DATA

# %%
x = df1[['Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
       'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
       'Delay_from_due_date', 'Num_of_Delayed_Payment',
       'Credit_Mix', 'Outstanding_Debt',
        'Monthly_Balance']]
y = df1[['Credit_Score']]

# %%
x.head()
# Out:
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       19114.12            1824.843333                  3                4
# 1       19114.12               0.000000                  3                4
# 2       19114.12               0.000000                  3                4
# 3       19114.12               0.000000                  3                4
# 4       19114.12            1824.843333                  3                4
#
#    Interest_Rate  Num_of_Loan  Delay_from_due_date  Num_of_Delayed_Payment  \
# 0              3            4                    3                       7
# 1              3            4                   -1                       0
# 2              3            4                    3                       7
# 3              3            4                    5                       4
# 4              3            4                    6                       0
#
#    Credit_Mix  Outstanding_Debt  Monthly_Balance
# ...

# %%
y.head(5)
# Out:
#    Credit_Score
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %% [markdown]
# # 4. Data Visualizations

# %% [markdown]
# #### 4.1 Countplot of Credit_Score

# %%
sns.countplot(x="Credit_Score",data=df1,palette= 'Set2')
# Out:
# <Axes: xlabel='Credit_Score', ylabel='count'>

# %% [markdown]
# #### 4.2 Number of Delayed Payments VS Credit Score

# %%
sns.barplot(x="Credit_Score", y=df1["Num_of_Delayed_Payment"].astype(float), data=df1)
# Out:
# <Axes: xlabel='Credit_Score', ylabel='Num_of_Delayed_Payment'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# # 5.MODEL Training

# %% [markdown]
# ### 5.1 LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_lr1 = lr.predict(x_test)
y_pred_lr1
# Out:
# array([1, 1, 2, ..., 1, 1, 1], shape=(20000,))

# %%
from sklearn.metrics import classification_report,r2_score,accuracy_score

# %%
accuracy_score(y_pred_lr1,y_test)*100
# Out:
# 30.225

# %%
cr = classification_report(y_pred_lr1,y_test)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.97      0.29      0.45     19418
#            2       0.03      0.56      0.06       582
#
#     accuracy                           0.30     20000
#    macro avg       0.33      0.28      0.17     20000
# weighted avg       0.95      0.30      0.44     20000

# %% [markdown]
# ### 5.2 DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dt1 = dt.predict(x_test)

# %%
cr = classification_report(y_pred_dt1,y_test)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.59      0.60      3634
#            1       0.69      0.69      0.69      5859
#            2       0.72      0.73      0.73     10507
#
#     accuracy                           0.69     20000
#    macro avg       0.67      0.67      0.67     20000
# weighted avg       0.69      0.69      0.69     20000

# %%
accuracy_score(y_pred_dt1,y_test)*100
# Out:
# 69.285

# %% [markdown]
# ### 5.3 RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rfc1 = rfc.predict(x_test)

# %%
cr = classification_report(y_pred_rfc1,y_test)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.73      0.71      3371
#            1       0.78      0.78      0.78      5894
#            2       0.80      0.79      0.79     10735
#
#     accuracy                           0.78     20000
#    macro avg       0.76      0.77      0.76     20000
# weighted avg       0.78      0.78      0.78     20000

# %%
accuracy_score(y_pred_rfc1,y_test)*100
# Out:
# 77.565

# %% [markdown]
# # 6. Applying SMOTE to resample Data

# %%
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler

# %%
x_train2,x_test2,y_train2,y_test2 = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#Feature Scaling
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train2)
x_test_scaled = scaler.transform(x_test2)

# %%
# Convert target to 1D
y_train2 =  y_train2.values.ravel()

# %%
# Apply SMOTE
smote = SMOTE(random_state=42)
x_resampled,y_resampled = smote.fit_resample(x_train_scaled,y_train2)

# %%
print("Before SMOTE:", pd.Series(y_train2).value_counts())
print("After SMOTE:", pd.Series(y_resampled).value_counts())
# Out:
# Before SMOTE: 2    42575
# 1    23124
# 0    14301
# Name: count, dtype: int64
# After SMOTE: 2    42575
# 0    42575
# 1    42575
# Name: count, dtype: int64

# %% [markdown]
# ## 7. Train Model on Resampled Data

# %% [markdown]
# #### 7.1 Logisitic Regression

# %% [markdown]
# #### A) Tranining of model

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_resampled,y_resampled)
# Out:
# LogisticRegression()

# %%
y_pred_lr2= lr.predict(x_test_scaled)
print("Accuracy:",accuracy_score(y_test2,y_pred_lr2)*100)
# Out:
# Accuracy: 60.6

# %%
cr_lr2 = classification_report(y_pred_lr2,y_test2)
print(cr_lr2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.18      0.30     19740
#            1       0.02      0.36      0.03       258
#            2       0.00      1.00      0.00         2
#
#     accuracy                           0.18     20000
#    macro avg       0.34      0.51      0.11     20000
# weighted avg       0.98      0.18      0.30     20000

# %% [markdown]
# #### B) Compare Accuracy Before and After SMOTE

# %%
print("Accuracy Before SMOTE is: ",accuracy_score(y_pred_lr1,y_test)*100)
print("Accuracy After SMOTE is: ", accuracy_score(y_test2,y_pred_lr2)*100)
# Out:
# Accuracy Before SMOTE is:  30.225
# Accuracy After SMOTE is:  60.6

# %% [markdown]
# #### C) REASON OF Accuracy Decreasing

# %% [raw]
# Before SMOTE:
# 1. DATA Is imbalanced
# 2. The model mostly predicts the majority class (e.g., "Good Credit Score"[2]) → High accuracy but bad performance for minority classes.
#
# After SMOTE:
# 1. The dataset is balanced
# 2. The model is forced to learn minority classes.
# 3. It predicts minority classes better → But overall accuracy can drop because it doesn't always guess the majority class anymore.

# %%
print("📊 Example:\n"
      "Model	   Accuracy	 Class-0 Recall	 Class-2 Recall \n"
      "Before SMOTE	   69%	      5%             88% \n"
      "After SMOTE        60%	      40%	     75% \n")
# Out:
# 📊 Example:
# Model	   Accuracy	 Class-0 Recall	 Class-2 Recall
# Before SMOTE	   69%	      5%             88%
# After SMOTE        60%	      40%	     75%

# %% [markdown]
# ## 7.2 DecisionTreeClassifier

# %% [markdown]
# #### A) Training of Model

# %%
from sklearn.tree import DecisionTreeClassifier
dt2 = DecisionTreeClassifier()
dt2.fit(x_resampled,y_resampled)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dt2 = dt2.predict(x_test_scaled)
print("Accuracy:",accuracy_score(y_test2,y_pred_dt2)*100)
# Out:
# Accuracy: 71.975

# %%
cr_dt2 = classification_report(y_pred_dt2,y_test2)
print(cr_dt2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.63      0.66      3805
#            1       0.74      0.71      0.72      6158
#            2       0.72      0.76      0.74     10037
#
#     accuracy                           0.72     20000
#    macro avg       0.71      0.70      0.71     20000
# weighted avg       0.72      0.72      0.72     20000

# %% [markdown]
# #### B) Compare Accuracy Before and After SMOTE

# %%
print("Accuracy Before SMOTE is: ",accuracy_score(y_pred_dt1,y_test)*100)
print("Accuracy After SMOTE is: ", accuracy_score(y_test2,y_pred_dt2)*100)
# Out:
# Accuracy Before SMOTE is:  69.285
# Accuracy After SMOTE is:  71.975

# %% [raw]
# Its accuracy is little bit increased due to well learning of model on Resample data

# %% [markdown]
# ## 7.3 RandomForestClassifier

# %% [markdown]
# #### A) Train Model

# %%
rfc2 = RandomForestClassifier()
rfc2.fit(x_resampled,y_resampled)
# Out:
# RandomForestClassifier()

# %%
y_pred_rfc2 = rfc2.predict(x_test_scaled)
print("Accuracy:",accuracy_score(y_test2,y_pred_rfc2)*100)
# Out:
# Accuracy: 77.145

# %%
cr_rfc2 = classification_report(y_pred_rfc2,y_test2)
print(cr_rfc2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.70      0.72      3694
#            1       0.78      0.77      0.78      5976
#            2       0.78      0.80      0.79     10330
#
#     accuracy                           0.77     20000
#    macro avg       0.77      0.76      0.76     20000
# weighted avg       0.77      0.77      0.77     20000

# %% [markdown]
# #### B) Compare Accuracy Before and After SMOTE

# %%
print("Accuracy Before SMOTE is: ",accuracy_score(y_test,y_pred_rfc1)*100)
print("Accuracy After SMOTE is: ", accuracy_score(y_test2,y_pred_rfc2)*100)
# Out:
# Accuracy Before SMOTE is:  77.565
# Accuracy After SMOTE is:  77.145

# %% [markdown]
# # 8. Improve Accuracy of RFC Model

# %% [markdown]
# #### A) RandomizedSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV, cross_val_score

# %%
params = {
    'n_estimators': [200, 300, 500],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2'],
    'bootstrap': [True, False]
}

# %%
rfc3 = RandomForestClassifier(random_state=42)
rfc3_search = RandomizedSearchCV(rfc3,param_distributions=params,n_iter=15,
              cv=3,scoring='f1_macro',n_jobs=-1,random_state=42)

# %%
rfc3_search.fit(x_resampled,y_resampled)
# Out:
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(random_state=42),
#                    n_iter=15, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [10, 20, None],
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [200, 300, 500]},
#                    random_state=42, scoring='f1_macro')

# %%
print("Best Parameters are: ",rfc3_search.best_params_)
# Out:
# Best Parameters are:  {'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': None, 'bootstrap': True}

# %%
best_rfc = rfc3_search.best_estimator_
best_rfc.fit(x_resampled,y_resampled)
y_pred_best = best_rfc.predict(x_test_scaled)

# %%
print("\n Final Accuracy:",accuracy_score(y_test2,y_pred_best)*100)
print("\n Classification Report:\n",classification_report(y_test2,y_pred_best))
# Out:
#  Final Accuracy: 77.34
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.74      0.72      3527
#            1       0.77      0.78      0.78      5874
#            2       0.80      0.78      0.79     10599
#
#     accuracy                           0.77     20000
#    macro avg       0.76      0.77      0.76     20000
# weighted avg       0.77      0.77      0.77     20000

# %% [markdown]
# ## B) Feature Importance

# %%
feat_imp = pd.Series(best_rfc.feature_importances_, index=x.columns).sort_values(ascending=False).head(15)
plt.figure(figsize=(8, 5))
sns.barplot(x=feat_imp, y=feat_imp.index, palette="viridis")
plt.title("Top 15 Important Features")
plt.show()

# %%
import pandas as pd

# ✅ Suppose you have trained best_rf (Random Forest model) from previous code
# ✅ And you have the same scaler (StandardScaler) used during training

# 🎯 New customer's data (example values)
new_data = {
    "Age": [32],
    "Annual_Income": [600000],
    "Monthly_Inhand_Salary": [50000],
    "Num_Bank_Accounts": [3],
    "Num_Credit_Card": [2],
    "Interest_Rate": [12],
    "Num_of_Loan": [2],
    "Delay_from_due_date": [4],
    "Num_of_Delayed_Payment": [1],
    "Changed_Credit_Limit": [20000],
    "Num_Credit_Inquiries": [1],
    "Credit_Mix": ["Good"],
    "Outstanding_Debt": [150000],
    "Credit_Utilization_Ratio": [35.0],
    "Credit_History_Age": ["3 Years 6 Months"],
    "Payment_of_Min_Amount": ["Yes"],
    "Total_EMI_per_month": [8000],
    "Amount_invested_monthly": [10000],
    "Payment_Behaviour": ["High_spent_Small_value_payments"],
    "Monthly_Balance": [20000]
}

# Convert to DataFrame
new_df = pd.DataFrame(new_data)

# Apply same preprocessing as training (Encoding + Scaling)
new_df_encoded = pd.get_dummies(new_df, drop_first=True)

missing_cols = set(x.columns) - set(new_df_encoded.columns)
for col in missing_cols:
    new_df_encoded[col] = 0
new_df_encoded = new_df_encoded[x.columns]  # Reorder columns

# Scale features
new_scaled = scaler.transform(new_df_encoded)

# Predict Credit Score
predicted_score = best_rfc.predict(new_scaled)
print("Predicted Credit Score:", predicted_score[0])
# Out:
# Predicted Credit Score: 0

# %%
print("0 Means  Good\n"
      "1 Means  Standard\n"
      "2 Means  Poor")
# Out:
# 0 Means  Good
# 1 Means  Standard
# 2 Means  Poor
